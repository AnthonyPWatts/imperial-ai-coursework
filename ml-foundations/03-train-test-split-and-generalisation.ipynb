# %% [markdown]
# # Train/Test Split and Generalisation
#
# ## Purpose
#
# Understand why a model should be evaluated on data it did not train on.
#
# ## Notebook status
#
# This is a placeholder notebook. It is intentionally an outline rather than a finished teaching notebook.
#
# The goal is to reserve the learning path while keeping the active project structure honest.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Draft section plan
#
# ### Fitting is not enough
#
# Explain why low error on training data does not guarantee a useful model.
#
# ### Split the data
#
# Separate examples into training and test sets.
#
# ### Train on one part
#
# Fit the model using only the training data.
#
# ### Evaluate on unseen data
#
# Calculate test error and compare it with training error.
#
# ### Generalisation
#
# Connect performance on unseen data to the usefulness of the model.

# %% [markdown]
# ## Notes for future build-out
#
# This should be practical ML workflow, not maths-refresh.

# %% [markdown]
# ## Summary placeholder
#
# This summary will be written once the worked examples and plots are in place.
