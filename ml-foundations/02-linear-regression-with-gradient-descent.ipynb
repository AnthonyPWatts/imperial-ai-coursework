# %% [markdown]
# # Linear Regression with Gradient Descent
#
# ## Purpose
#
# Fit a simple linear regression model using gradient descent instead of a direct least-squares solver.
#
# ## Notebook status
#
# This is a placeholder notebook. It is intentionally an outline rather than a finished teaching notebook.
#
# The goal is to reserve the learning path while keeping the active project structure honest.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Draft section plan
#
# ### Same model, different solver
#
# Revisit $\hat{\mathbf{y}} = X\boldsymbol{\beta}$ from linear regression.
#
# ### Use mean squared error
#
# Define the loss that gradient descent will minimise.
#
# ### Initialise parameters
#
# Start with deliberately rough parameter values.
#
# ### Update repeatedly
#
# Use gradients to improve the parameters step by step.
#
# ### Compare with least squares
#
# Show that both approaches are trying to reach the same kind of fit.

# %% [markdown]
# ## Notes for future build-out
#
# This bridges optimisation into an actual ML training loop.

# %% [markdown]
# ## Summary placeholder
#
# This summary will be written once the worked examples and plots are in place.
