# %% [markdown]
# # Linear Regression from Scratch
#
# ## Purpose
#
# Build a tiny linear regression model manually using NumPy, without hiding the linear algebra.
#
# ## Notebook status
#
# This is a placeholder notebook. It is intentionally an outline rather than a finished teaching notebook.
#
# The goal is to reserve the learning path while keeping the active project structure honest.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Draft section plan
#
# ### A tiny dataset
#
# Create a small dataset with one input feature and one target.
#
# ### Build the design matrix
#
# Add the intercept column and inspect the shape of $X$.
#
# ### Solve for the parameters
#
# Use least squares to estimate $\boldsymbol{\beta}$.
#
# ### Make predictions
#
# Compute $\hat{\mathbf{y}} = X\boldsymbol{\beta}$.
#
# ### Evaluate the fit
#
# Calculate residuals and mean squared error.

# %% [markdown]
# ## Notes for future build-out
#
# This belongs in ML foundations because it is now a model-building workflow.

# %% [markdown]
# ## Summary placeholder
#
# This summary will be written once the worked examples and plots are in place.
