# %% [markdown]
# # Loss Functions
#
# ## Purpose
#
# Understand loss as a single number that measures how wrong a model is.
#
# ## Notebook status
#
# This is a placeholder notebook. It is intentionally an outline rather than a finished teaching notebook.
#
# The goal is to reserve the learning path while keeping the active project structure honest.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Draft section plan
#
# ### Predictions and errors
#
# Start from $\mathbf{y}$, $\hat{\mathbf{y}}$, and residuals.
#
# ### Squared error
#
# Show why squared residuals lead naturally to least squares.
#
# ### Mean squared error
#
# Average squared errors to get a scale-friendly loss value.
#
# ### Mean absolute error
#
# Briefly contrast MAE with MSE without turning this into a metrics reference.
#
# ### Loss as an optimisation target
#
# Connect loss to the idea of finding better parameters.

# %% [markdown]
# ## Notes for future build-out
#
# Keep the emphasis on maths intuition, not sklearn metrics yet.

# %% [markdown]
# ## Summary placeholder
#
# This summary will be written once the worked examples and plots are in place.
