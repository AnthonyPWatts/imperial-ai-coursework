# %% [markdown]
# # Gradients
#
# ## Purpose
#
# Build intuition for gradients as the direction a function increases most quickly.
#
# ## Notebook status
#
# This is a placeholder notebook. It is intentionally an outline rather than a finished teaching notebook.
#
# The goal is to reserve the learning path while keeping the active project structure honest.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Draft section plan
#
# ### From slope to gradient
#
# Start with a one-dimensional slope and extend the idea to more than one input.
#
# ### A simple surface
#
# Use a small function of two variables that can be visualised clearly.
#
# ### Gradient vectors
#
# Show gradient arrows on a contour plot.
#
# ### Uphill and downhill
#
# Explain why the negative gradient points downhill.
#
# ### Why gradients matter for ML
#
# Connect gradients to changing model parameters to reduce loss.

# %% [markdown]
# ## Notes for future build-out
#
# Keep calculus gentle: enough for optimisation intuition, not a calculus textbook.

# %% [markdown]
# ## Summary placeholder
#
# This summary will be written once the worked examples and plots are in place.
